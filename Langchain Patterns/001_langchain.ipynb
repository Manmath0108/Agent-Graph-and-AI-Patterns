# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ### 1. Messages - The Building Blocks

# %%
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
from langchain_ollama import ChatOllama

# %%
llm = ChatOllama(model="gemma3",
                base_url="http://localhost:11434",
                temperature=0.7,
                max_tokens=1024,
                num_ctx=2048)

# %%
llm
# Out:
# ChatOllama(model='gemma3', num_ctx=2048, temperature=0.7, base_url='http://localhost:11434')

# %% [markdown]
# ### Types of messages provided by langchain
# * **HumanMessage**: Prompt or the Query asked by the user to the LLM
#
# * **SystemMessage**: Set by the developer so that the Model behaves in a certain way (Can also be set by the user itself)
#
# * **AIMessage**: Response given by the LLM
#
# All these three are supposed to be provided in the form of a list

# %%
messages = [
    SystemMessage(content="You are a helpful assistant."),
    HumanMessage(content="What is Langchain?")
]
messages
# Out:
# [SystemMessage(content='You are a helpful assistant.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='What is Langchain?', additional_kwargs={}, response_metadata={})]

# %%
response = llm.invoke(messages)

# %%
response
# Out:
# AIMessage(content='Okay, let\'s break down what Langchain is! It\'s a really exciting and rapidly evolving framework designed to make it *much* easier to build applications powered by large language models (LLMs) like GPT-3, GPT-4, PaLM 2, and others.\n\nHere\'s a breakdown of key aspects:\n\n**1. What it *is*:**\n\n* **A Framework, Not a Model:**  Crucially, Langchain isn\'t a language model itself. It’s a toolkit and set of abstractions that helps you *use* existing LLMs more effectively. Think of it like a toolbox for building LLM-powered apps.\n* **Modular Design:** It’s built around modular components, meaning you can pick and choose the parts you need for your specific application.\n* **Python-First:** Primarily designed for Python developers, though it’s expanding to other languages.\n\n\n**2. What it *does* – The Core Components:**\n\nLangchain provides building blocks to handle the complexities of working with LLMs. Here are some of the most important:\n\n* **Models:**  Interfaces for interacting with various LLMs (OpenAI, Cohere, Hugging Face, etc.).  It handles things like authentication, API calls, and rate limiting.\n* **Prompts:** Tools for constructing and managing prompts – the text you feed into the LLM. Langchain offers templates and ways to dynamically generate prompts based on user input or data.\n* **Chains:** This is a *huge* part of Langchain. Chains are sequences of calls to LLMs or other utilities. They let you create complex workflows, like:\n    * **Simple Chains:** Just calling an LLM once.\n    * **Sequential Chains:**  One LLM call feeds into another (e.g., one LLM summarizes a document, then another answers questions based on the summary).\n    * **Agent Chains:**  The most powerful – Agents can *decide* which tools to use to answer a question, making them incredibly flexible.\n* **Memory:** LLMs are stateless by default – they don’t remember previous interactions. Langchain provides mechanisms to add memory to your chains, allowing them to have context.  This is vital for conversational applications.  Different types of memory are available (e.g., storing conversation history, using a knowledge base).\n* **Document Loaders:**  Tools for loading data from various sources – PDFs, websites, databases, etc. – and transforming it into a format that LLMs can understand.\n* **Retrieval:**  Ways to retrieve relevant information from your data to feed into the LLM. This is critical for building applications that answer questions about specific documents or knowledge bases (often called "Retrieval-Augmented Generation" or RAG).\n* **Callbacks:**  Mechanisms for logging, monitoring, and debugging your Langchain applications.\n\n\n**3. Why it’s useful:**\n\n* **Reduces Boilerplate:**  Langchain handles a lot of the low-level details, so you can focus on the *logic* of your application.\n* **Streamlines Complex Workflows:**  Chains make it easy to build sophisticated LLM-powered applications.\n* **RAG (Retrieval-Augmented Generation):**  It’s a key enabler for building applications that combine the power of LLMs with the ability to access and use external knowledge.\n* **Rapid Prototyping:**  The modular design and readily available components make it faster to experiment and build proof-of-concepts.\n\n**4. Resources to Learn More:**\n\n* **Official Langchain Website:** [https://www.langchain.com/](https://www.langchain.com/) - This is the best place to start.\n* **Langchain Documentation:** [https://python.langchain.com/](https://python.langchain.com/) -  Detailed documentation and examples.\n* **Langchain Tutorials:** [https://www.langchain.com/tutorials](https://www.langchain.com/tutorials) -  Step-by-step tutorials.\n\n---\n\n**In short, Langchain is a powerful framework that simplifies the process of building applications with large language models, making it more accessible and efficient.**\n\nTo help me give you even more targeted information, could you tell me:\n\n*   What are you hoping to *do* wit ...

# %%
response.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# Okay, let's break down what Langchain is! It's a really exciting and rapidly evolving framework designed to make it *much* easier to build applications powered by large language models (LLMs) like GPT-3, GPT-4, PaLM 2, and others.
#
# Here's a breakdown of key aspects:
#
# **1. What it *is*:**
#
# * **A Framework, Not a Model:**  Crucially, Langchain isn't a language model itself. It’s a toolkit and set of abstractions that helps you *use* existing LLMs more effectively. Think of it like a toolbox for building LLM-powered apps.
# * **Modular Design:** It’s built around modular components, meaning you can pick and choose the parts you need for your specific application.
# * **Python-First:** Primarily designed for Python developers, though it’s expanding to other languages.
#
#
# **2. What it *does* – The Core Components:**
#
# Langchain provides building blocks to handle the complexities of working with LLMs. Here are some of the most important:
#
# * **Models:**  Interfaces for interacting with various LLMs (OpenAI, Cohere, Hugging Face, etc.).  It handles things like authentication, API calls, and rate limiting.
# * **Prompts:** Tools for constructing and managing prompts – the text you feed into the LLM. Langchain offers templates and ways to dynamically generate prompts based on user input or data.
# * **Chains:** This is a *huge* part of Langchain. Chains are sequences of calls to LLMs or other utilities. They let you create complex workflows, like:
#     * **Simple Chains:** Just calling an LLM once.
#     * **Sequential Chains:**  One LLM call feeds into another (e.g., one LLM summarizes a document, then another answers questions based on the summary).
#     * **Agent Chains:**  The most powerful – Agents can *decide* which tools to use to answer a question, making them incredibly flexible.
# * **Memory:** LLMs are stateless by default – they don’t remember previous interactions. Langchain provides mechanisms to add memory to your chains, allowing them to have context.  This is vital for conversational applications.  Different types of memory are available (e.g., storing conversation history, using a knowledge base).
# * **Document Loaders:**  Tools for loading data from various sources – PDFs, websites, databases, etc. – and transforming it into a format that LLMs can understand.
# * **Retrieval:**  Ways to retrieve relevant information from your data to feed into the LLM. This is critical for building applications that answer questions about specific documents or knowledge bases (often called "Retrieval-Augmented Generation" or RAG).
# * **Callbacks:**  Mechanisms for logging, monitoring, and debugging your Langchain applications.
#
#
# **3. Why it’s useful:**
#
# * **Reduces Boilerplate:**  Langchain handles a lot of the low-level details, so you can focus on the *logic* of your application.
# * **Streamlines Complex Workflows:**  Chains make it easy to build sophisticated LLM-powered applications.
# * **RAG (Retrieval-Augmented Generation):**  It’s a key enabler for building applications that combine the power of LLMs with the ability to access and use external knowledge.
# * **Rapid Prototyping:**  The modular design and readily available components make it faster to experiment and build proof-of-concepts.
#
# **4. Resources to Learn More:**
#
# * **Official Langchain Website:** [https://www.langchain.com/](https://www.langchain.com/) - This is the best place to start.
# * **Langchain Documentation:** [https://python.langchain.com/](https://python.langchain.com/) -  Detailed documentation and examples.
# * **Langchain Tutorials:** [https://www.langchain.com/tutorials](https://www.langchain.com/tutorials) -  Step-by-step tutorials.
#
# ---
#
# **In short, Langchain is a powerful framework that simplifies the process of building applications with large language models, making it more accessible and efficient.**
#
# To help me give you even more targeted information, could you tell me:
#
# *   What are you hoping to *do* with Langchain? (e.g., build a chatbot, answer questions about a specific dataset, etc.)

# %% [markdown]
# ### 2. Prompt Template - Reusable Prompts
#
# As mentioned it is like a reusable set of prompts, where in the provided template we can pass our system message, human message and recieve an AI message using a reusable template

# %%
from langchain_core.prompts import ChatPromptTemplate

# %%
prompt = ChatPromptTemplate([
    ("system", "You are an expert in {subject}. Explain it to a {audience}."),
    ("human", "Can you explain {topic}?")
])

# %%
prompt
# Out:
# ChatPromptTemplate(input_variables=['audience', 'subject', 'topic'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=['audience', 'subject'], input_types={}, partial_variables={}, template='You are an expert in {subject}. Explain it to a {audience}.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['topic'], input_types={}, partial_variables={}, template='Can you explain {topic}?'), additional_kwargs={})])

# %%
messages = prompt.invoke({
    "subject": "Physics",
    "audience": "High School Students",
    "topic": "Quantum Mechanics"
})
messages
# Out:
# ChatPromptValue(messages=[SystemMessage(content='You are an expert in Physics. Explain it to a High School Students.', additional_kwargs={}, response_metadata={}), HumanMessage(content='Can you explain Quantum Mechanics?', additional_kwargs={}, response_metadata={})])

# %%
response = llm.invoke(messages)

# %%
response.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# Okay, let’s tackle Quantum Mechanics. It’s a notoriously weird and wonderful part of physics, and honestly, even physicists still debate some of its implications! But I’ll break it down for you in a way that hopefully makes sense.
#
# **The Big Picture: Classical Physics vs. Quantum**
#
# For centuries, we understood the universe through what we called “Classical Physics.” Think Newton – things moved predictably, followed definite paths, and had definite properties like position and speed. If you throw a ball, you can, with pretty good accuracy, predict where it will land.  That’s because the world is governed by forces and predictable laws.
#
# Quantum Mechanics throws a serious wrench into that picture. It describes the behavior of matter and energy at the *very* small scale – atoms, electrons, photons (light particles) – where these classical rules just don’t hold anymore.
#
# **Here’s the core of what makes Quantum Mechanics so strange:**
#
# **1. Quantization – It's Not Continuous!**
#
# * **Think of it like this:** Imagine a ramp. You can stand anywhere on the ramp, and your height can be any value.  Now imagine a staircase. You can only stand on specific steps.
# * **Quantum mechanics says energy, momentum, and other properties aren’t continuous.** They come in discrete packets called "quanta."  Like steps on a staircase, energy can only exist in specific amounts. This is why it's called “quantum” – it’s about these tiny, quantized amounts.
# * **Example:** An electron in an atom can only exist at specific energy levels. It can’t have *any* energy value between those levels.
#
#
# **2. Wave-Particle Duality – It's Both!**
#
# * **This is *the* mind-bending part.** Quantum objects, like electrons and photons, sometimes behave like waves and sometimes behave like particles.
# * **Wave Behavior:** Waves spread out and have properties like wavelength and frequency. Think of ripples in a pond.
# * **Particle Behavior:** Particles are localized – they have a specific position.
# * **The famous Double-Slit Experiment:**  If you shoot electrons through two slits, you’d expect them to create two distinct bands on a screen behind the slits. But they *don’t*. Instead, they create an interference pattern, like waves! This suggests that each electron is going through *both* slits simultaneously, interfering with itself.  It's only when you try to observe which slit the electron goes through that the wave-like behavior disappears, and it acts like a particle.
#
# **3. Uncertainty Principle – You Can't Know Everything**
#
# * **Developed by Werner Heisenberg:** This principle states that there’s a fundamental limit to how accurately you can know certain pairs of properties of a particle *at the same time*.
# * **Specifically:** The more accurately you know a particle’s position, the less accurately you know its momentum (and vice versa). It’s not a limitation of our instruments; it’s a fundamental property of the universe.
# * **Analogy:** Imagine trying to pinpoint the location of a hummingbird while also measuring its speed. The act of trying to measure its speed will inevitably disturb its flight and change its position.
#
#
# **4. Probability – It's All About Possibilities**
#
# * **Quantum mechanics doesn’t tell us exactly where a particle *will* be.** Instead, it tells us the *probability* of finding it in a particular location.
# * **The Wave Function:** This mathematical function describes the probability distribution of a particle’s properties.  A high value in the wave function means a high probability of finding the particle there.
#
# **Key Takeaways:**
#
# * **Quantum mechanics deals with the very small.** It’s essential for understanding atoms, molecules, and the forces that hold them together.
# * **It’s probabilistic, not deterministic.** We can’t predict the future with certainty at the quantum level.
# * **It’s counterintuitive.**  It challenges our everyday understanding of how the world works.
#
# **Why Does It Matter?**
#
# Quantum mechanics isn't just a weird theoretical concept. It's the foundation for:
#
# * **Lasers**
# * **Transistors (and therefore computers!)**
# * **Medical imaging (MRI)**
# * **Nuclear energy**
#
#
# **Resources for Further Learning:**
#
# * **Hyperphysics:** [https://hyperphysics.phy-astr.gsu.edu/hbase/quantum/index.html](https://hyperphysics.phy-astr.gsu.edu/hbase/quantum/index.html)
# * **Khan Academy Physics:** [https://www.khanacademy.org/science/physics/quantum-physics](https://www.khanacademy.org/science/physics/quantum-physics)
#
# ---
#
# **Do you want me to delve deeper into a specific aspect of Quantum Mechanics, like:**
#
# *   The Double-Slit Experiment in more detail?
# *   The mathematical basis (wave functions)?
# *   How quantum mechanics applies to a specific technology (like lasers)?

# %%
messages = prompt.invoke({
    "subject": "Physics",
    "audience": "High School Students",
    "topic": "Quantum Mechanics"
})
response = llm.invoke(messages)
response.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# Okay, let's tackle Quantum Mechanics. It’s arguably the most mind-bending, yet incredibly successful, branch of physics out there.  It deals with the incredibly tiny – atoms and the particles *within* them – and it describes a world that’s fundamentally different from our everyday experience.
#
# Here’s a breakdown, broken down into key concepts, aimed at a high school level:
#
# **1. The Problem with Classical Physics:**
#
# Before quantum mechanics, we had classical physics – Newton’s laws of motion, Maxwell’s electromagnetism. These worked *great* for describing things we can see and interact with directly: planets orbiting the sun, a baseball flying through the air, a car moving down the road. However, when scientists started looking at things at the atomic level, things started to break down. Classical physics couldn’t explain a lot of the observed behavior of matter and energy.
#
# **2. Key Concepts - It’s Weird!**
#
# * **Quantization:** The word “quantum” comes from “quant,” meaning a discrete amount. This is the *big* idea. Energy, momentum, and other properties aren't continuous like a ramp. Instead, they come in specific, fixed packets called “quanta.” Think of it like this: you can't buy half a marble – you have to buy whole ones. Similarly, an electron can only absorb or emit energy in specific, defined amounts.
#
# * **Wave-Particle Duality:** This is probably the most famous and strangest concept. Quantum objects – like electrons and photons (light particles) – can behave as *both* waves and particles.
#     * **Waves:** Waves spread out and exhibit properties like interference (where waves combine to make bigger or smaller waves) and diffraction (where waves bend around obstacles).
#     * **Particles:** Particles are localized objects with definite position and momentum.
#     * **The Experiment:** The famous double-slit experiment demonstrates this beautifully.  When you shoot electrons through two slits, they create an interference pattern on a screen – like waves! But if you try to observe *which* slit the electron goes through, the interference pattern disappears, and you get a particle pattern. It's as if the act of observing changes the behavior!
#
#
# * **Heisenberg Uncertainty Principle:** This principle states that there's a fundamental limit to how accurately we can know certain pairs of properties of a particle *at the same time*.  Specifically, the more precisely you know a particle’s position, the less precisely you can know its momentum (and vice versa). It's not a limitation of our instruments; it's a fundamental property of the universe.  It’s like trying to pinpoint the location of a fast-moving car – the moment you try to measure its exact position, it’s already moved a little bit.
#
# * **Probability and Wave Functions:**  Instead of knowing exactly where a particle is, quantum mechanics describes the *probability* of finding it in a certain location. This probability is described by a mathematical function called a "wave function" (represented by the Greek letter Ψ – psi). The square of the wave function gives you the probability density.  So, Ψ doesn't tell you *where* the particle is, but rather the chances of finding it there.
#
#
# **3. Mathematical Description (A Little Bit):**
#
# Quantum mechanics is built on equations, primarily the Schrödinger equation. This equation describes how the wave function of a particle evolves over time. It's a complex equation, but it’s the foundation of the theory.
#
# **4. Why Does It Matter?**
#
# Despite its strangeness, quantum mechanics is incredibly successful. It’s the basis for:
#
# * **Lasers:** Based on stimulated emission of photons.
# * **Transistors and Microchips:** The building blocks of computers and modern electronics.
# * **Medical Imaging (MRI):** Relies on the quantum properties of atomic nuclei.
# * **Nuclear Energy:** Understanding nuclear reactions.
#
# **Important Note:** Quantum mechanics is *not* about making things smaller. It's about describing the fundamental nature of reality at the smallest scales.
#
#
# **Resources to Explore Further:**
#
# * **Hyperphysics:** [http://hyperphysics.phy-astr.gsu.edu/hbase/quantum/index.html](http://hyperphysics.phy-astr.gsu.edu/hbase/quantum/index.html)
# * **Khan Academy - Quantum Physics:** [https://www.khanacademy.org/science/physics/quantum-physics](https://www.khanacademy.org/science/physics/quantum-physics)
#
#
# ---
#
# **Do you want me to delve deeper into a specific aspect of quantum mechanics, such as:**
#
# *   The double-slit experiment in more detail?
# *   The Schrödinger equation?
# *   Quantum entanglement?
# *   Or perhaps you have a specific question you’d like me to answer?

# %% [markdown]
# ### 3. LCEL - Chains with Pipe Operator
#
# Anything which can be operated using the  `invoke` command is called a lanchain runnable
# For eg:
# * llm or prompt (from the above the above examples)

# %%
chain = prompt | llm

# %%
response = chain.invoke({
    "subject": "Physics",
    "audience": "Middle School Students",
    "topic": "Relativity"
})
response.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# Okay, let’s tackle Relativity! It sounds super complicated, and honestly, it *is* a bit mind-bending, but we can break it down into chunks that make sense.  It's actually two main ideas developed by Albert Einstein, and they changed the way we think about space and time.
#
# **1. Special Relativity (1905) - The Basics**
#
# Imagine you're on a train moving really smoothly at a constant speed. You toss a ball straight up in the air. To you, the ball just goes straight up and down.
#
# But to someone standing *outside* the train, watching you, the ball is going up and down *and* moving forward along with the train!
#
# That's the core idea of Special Relativity. It says that **motion is relative**.  There’s no single “correct” way to describe how something is moving – it depends on who’s observing it.
#
# Here are the two big rules Einstein came up with:
#
# * **The Laws of Physics are the Same for Everyone in Uniform Motion:**  This means that if you do an experiment on the train (like tossing that ball), you'll get the same results as someone standing still on the ground. The laws of physics – gravity, how things move – work the same no matter how fast you're moving smoothly.
#
# * **The Speed of Light is Constant:** This is the *really* weird one. Einstein realized that the speed of light in a vacuum (like outer space) is always the same for *everyone*, no matter how fast they’re moving.  It’s like a universal speed limit – 299,792,458 meters per second (about 186,282 miles per second!).
#
#
# **What does this mean?  Time and Space are Connected!**
#
# Because the speed of light is constant, something strange happens with time and space.
#
# * **Time Dilation:**  Time can actually pass differently for people moving at different speeds. The faster you move, the slower time passes *for you* relative to someone who’s not moving as fast.  It’s not something you’d notice in everyday life because we don't move anywhere near the speed of light, but it’s a real effect.
#
# * **Length Contraction:**  Objects also appear shorter in the direction they're moving, the faster they go. Again, this is only noticeable at extremely high speeds.
#
#
#
# **2. General Relativity (1915) - Gravity is Weird Too!**
#
# Special Relativity deals with things moving at constant speeds. General Relativity deals with gravity.
#
# Einstein realized that gravity isn’t a *force* in the traditional sense (like magnetism). Instead, **gravity is caused by the warping of space and time!**
#
# Think of it like this:
#
# * Imagine a bowling ball placed on a stretched-out rubber sheet. It creates a dip, right?
# * Now, if you roll a marble across the sheet, it will curve *towards* the bowling ball, not because the bowling ball is "pulling" it, but because the marble is following the curved path created by the dip.
#
# That's what massive objects like the Earth and the Sun do to space and time. They warp it, and other objects (like planets and light) follow those curves.  This is what we experience as gravity!
#
# **Key Takeaways:**
#
# * **Relativity is about perspective:**  How we see things depends on our motion.
# * **The speed of light is the ultimate speed limit.**
# * **Gravity isn't a force, it's a curve in space and time.**
#
#
# **Important Note for Middle Schoolers:**  Relativity is incredibly complex, and even scientists are still exploring its implications. We’ve simplified it here to give you a basic understanding.
#
# ---
#
# **Do you want me to:**
#
# *   Explain a specific part of relativity in more detail (like time dilation or length contraction)?
# *   Give you a simple example to illustrate a concept?
# *   Talk about some of the cool experiments that have proven Einstein's theories?

# %% [markdown]
# The above code simply creates a chain using LCEL (Langchain EXpression Language)
# Here  `chain = prompt | llm ` makes a chain where the flow of execution happens in the following order:
#
# * prompt is invoked -> The llm is invoked based on the prompt executed before in the chain

# %% [markdown]
# ### 4. Adding Output Parser

# %%
from langchain_core.output_parsers import StrOutputParser

# %%
chain = prompt | llm | StrOutputParser()

# %%
response = chain.invoke({
    "subject": "Physics",
    "audience": "Middle School",
    "topic": "Relativity"
})
response
# Out:
# 'Okay, let’s tackle Relativity! It sounds super complicated, and honestly, it *is* a bit mind-bending, but we can break it down. It’s mostly thanks to a brilliant scientist named Albert Einstein, and it completely changed how we think about space and time.\n\n**The Big Idea: It’s All Relative!**\n\nThe word "relativity" means that things aren\'t always the same for everyone. It’s like this: your experience of something depends on *where you are* and *how fast you’re moving*. That’s the core of Einstein\'s ideas.\n\n**There are actually *two* parts to Relativity:**\n\n**1. Special Relativity (1905):  Dealing with Constant Speed**\n\n* **The Constant Speed of Light:** This is the weirdest and most important part. Einstein realized that the speed of light in a vacuum (like space) is *always* the same, no matter how fast you\'re moving towards it or away from it.  Think about it like this: if you’re in a car and shine a flashlight forward, you might think the light is going faster than usual. But Einstein said *no*, the light is *still* traveling at the same speed – about 671 million miles per hour!  It’s a fundamental rule of the universe.\n\n* **Time Dilation:** Because the speed of light is constant, time itself can appear to slow down for things moving very, very fast. Imagine you\'re on a super-fast rocket zooming past Earth.  To someone on Earth watching you, your clock on the rocket would appear to be ticking slower than their clock.  It’s not that *you* feel time slowing down, but *they* would see it that way.  It’s a subtle effect, you wouldn’t notice it in everyday life, but it’s real!\n\n* **Length Contraction:** Similarly, objects moving very fast appear shorter in the direction they\'re moving to someone who is standing still. \n\n\n**2. General Relativity (1915): Gravity is a Curve!**\n\n* **Gravity Isn’t a Force (Exactly):**  Newton thought gravity was a force pulling things together. Einstein realized something even cooler: gravity is actually caused by *space and time* being curved by massive objects! \n\n* **Imagine a Trampoline:**  Think of a trampoline. If you put a bowling ball in the middle, it creates a dip, right? Now, if you roll a marble across the trampoline, it will curve *towards* the bowling ball. That\'s kind of like what happens with gravity.  Massive objects like planets and stars warp space and time around them, and other objects follow those curves. \n\n* **Light Bends Too:** Because space and time are curved, even light bends when it passes near a massive object! Scientists have actually observed this happening.\n\n**Important Points to Remember:**\n\n* **It\'s all relative:**  The effects of relativity become noticeable when you\'re moving at speeds close to the speed of light.\n* **It’s been proven!**  Relativity isn\'t just a theory; it’s been repeatedly tested and confirmed through experiments.  GPS satellites, for example, have to account for the effects of relativity to work accurately.\n\n**Resources for Further Exploration:**\n\n* **NASA Kids’ Club - Relativity:** [https://science.nasa.gov/kidsclub/relativity/](https://science.nasa.gov/kidsclub/relativity/)\n* **PBS - Relativity:** [https://www.pbs.org/wgbh/nova/relativity/](https://www.pbs.org/wgbh/nova/relativity/)\n\n\n**Do you want me to:**\n\n*   Go into more detail about a specific part of relativity (like time dilation or how gravity works)?\n*   Try to explain it with a different example?\n*   Answer a specific question you have about it?'

# %% [markdown]
# In the above cell, as we can clearly see that `StrOutputParser` is also a langchain runnable, so it can also be added to the chain
#
# * `StrOutputParser`: parses the AI Message and presents it in Markdown

# %%
print(response)
# Out:
# Okay, let’s tackle Relativity! It sounds super complicated, and honestly, it *is* a bit mind-bending, but we can break it down. It’s mostly thanks to a brilliant scientist named Albert Einstein, and it completely changed how we think about space and time.
#
# **The Big Idea: It’s All Relative!**
#
# The word "relativity" means that things aren't always the same for everyone. It’s like this: your experience of something depends on *where you are* and *how fast you’re moving*. That’s the core of Einstein's ideas.
#
# **There are actually *two* parts to Relativity:**
#
# **1. Special Relativity (1905):  Dealing with Constant Speed**
#
# * **The Constant Speed of Light:** This is the weirdest and most important part. Einstein realized that the speed of light in a vacuum (like space) is *always* the same, no matter how fast you're moving towards it or away from it.  Think about it like this: if you’re in a car and shine a flashlight forward, you might think the light is going faster than usual. But Einstein said *no*, the light is *still* traveling at the same speed – about 671 million miles per hour!  It’s a fundamental rule of the universe.
#
# * **Time Dilation:** Because the speed of light is constant, time itself can appear to slow down for things moving very, very fast. Imagine you're on a super-fast rocket zooming past Earth.  To someone on Earth watching you, your clock on the rocket would appear to be ticking slower than their clock.  It’s not that *you* feel time slowing down, but *they* would see it that way.  It’s a subtle effect, you wouldn’t notice it in everyday life, but it’s real!
#
# * **Length Contraction:** Similarly, objects moving very fast appear shorter in the direction they're moving to someone who is standing still.
#
#
# **2. General Relativity (1915): Gravity is a Curve!**
#
# * **Gravity Isn’t a Force (Exactly):**  Newton thought gravity was a force pulling things together. Einstein realized something even cooler: gravity is actually caused by *space and time* being curved by massive objects!
#
# * **Imagine a Trampoline:**  Think of a trampoline. If you put a bowling ball in the middle, it creates a dip, right? Now, if you roll a marble across the trampoline, it will curve *towards* the bowling ball. That's kind of like what happens with gravity.  Massive objects like planets and stars warp space and time around them, and other objects follow those curves.
#
# * **Light Bends Too:** Because space and time are curved, even light bends when it passes near a massive object! Scientists have actually observed this happening.
#
# **Important Points to Remember:**
#
# * **It's all relative:**  The effects of relativity become noticeable when you're moving at speeds close to the speed of light.
# * **It’s been proven!**  Relativity isn't just a theory; it’s been repeatedly tested and confirmed through experiments.  GPS satellites, for example, have to account for the effects of relativity to work accurately.
#
# **Resources for Further Exploration:**
#
# * **NASA Kids’ Club - Relativity:** [https://science.nasa.gov/kidsclub/relativity/](https://science.nasa.gov/kidsclub/relativity/)
# * **PBS - Relativity:** [https://www.pbs.org/wgbh/nova/relativity/](https://www.pbs.org/wgbh/nova/relativity/)
#
#
# **Do you want me to:**
#
# *   Go into more detail about a specific part of relativity (like time dilation or how gravity works)?
# *   Try to explain it with a different example?
# *   Answer a specific question you have about it?

# %% [markdown]
# ### 5. Streaming Responses and Structured Output (Pydantic)

# %%
from pydantic import BaseModel, Field

# %%
class Sentiment(BaseModel):
    sentiment: bool = Field(..., description="True if the sentiment is positive, False otherwise")
    reasoning: str = Field(..., description="A brief explanation of the sentiment")

# %%
structured_llm = llm.with_structured_output(Sentiment)

# %%
structured_llm
# Out:
# RunnableBinding(bound=ChatOllama(model='gemma3', num_ctx=2048, temperature=0.7, base_url='http://localhost:11434'), kwargs={'format': {'properties': {'sentiment': {'description': 'True if the sentiment is positive, False otherwise', 'title': 'Sentiment', 'type': 'boolean'}, 'reasoning': {'description': 'A brief explanation of the sentiment', 'title': 'Reasoning', 'type': 'string'}}, 'required': ['sentiment', 'reasoning'], 'title': 'Sentiment', 'type': 'object'}, 'ls_structured_output_format': {'kwargs': {'method': 'json_schema'}, 'schema': <class '__main__.Sentiment'>}}, config={}, config_factories=[])
# | PydanticOutputParser(pydantic_object=<class '__main__.Sentiment'>)

# %%
response = structured_llm.invoke("I love Programming")
response
# Out:
# Sentiment(sentiment=True, reasoning="The user stated, 'I love Programming,' which is a positive statement expressing enthusiasm.")

# %%
response.model_dump_json()
# Out:
# '{"sentiment":true,"reasoning":"The user stated, \'I love Programming,\' which is a positive statement expressing enthusiasm."}'

# %%
response.model_dump()
# Out:
# {'sentiment': True,
#  'reasoning': "The user stated, 'I love Programming,' which is a positive statement expressing enthusiasm."}

# %% [markdown]
# Streaming makes it look as if the llm is typing, What actually happens is that Data is presented as it gets generated by the LLM in real time

# %%
for chunk in llm.stream("I love History, Write a Poem about it"):
    print(chunk.content, end='', flush=True)
# Out:
# Okay, here's a poem about history, aiming to capture its vastness, mystery, and enduring power:
#
# **Echoes in the Stone**
#
# The dust of ages settles deep,
# On empires risen, secrets sleep.
# A whisper carried on the breeze,
# Through crumbling walls and ancient trees.
#
# From hunter’s hand to bronze’s first gleam,
# A tapestry of a forgotten dream.
# The pyramids stand, a silent plea,
# Of Pharaohs lost for all to see.
#
# The legions marched, a disciplined tide,
# Across the lands, where heroes died.
# The Roman roads, a network spun,
# Connecting worlds beneath the sun.
#
# The Dark Ages veiled a shadowed grace,
# Then Renaissance bloomed with vibrant space.
# Ideas ignited, bold and bright,
# Challenging darkness with their light.
#
# Revolution’s fire, a fervent call,
# To break the chains and stand up tall.
# From Waterloo’s fields to Gettysburg’s pain,
# The echoes of the past remain.
#
# Each artifact, a story told,
# In fragments found, both new and old.
# A puzzle waiting to unfold,
# Of humankind, brave, foolish, bold.
#
# So listen close, and you will find,
# The lessons woven for humankind.
# For history’s breath, a constant flow,
# Shapes who we are, and where we go.
#
#
# ---
#
# Would you like me to:
#
# *   Try a poem with a specific historical focus (e.g., Ancient Rome, World War II)?
# *   Adjust the tone or style of the poem (e.g., more melancholic, more hopeful)?
